# %% [markdown]
# # First Deep Learning Model

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_circles

# %%
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5,1,'Blue circles and Red crosses')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

# %%
model.add(Dense(4, input_shape=(2,), activation='tanh'))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /home/aims/.local/lib/python2.7/site-packages/tensorflow/python/ops/nn_impl.py:180: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.fit(X, y, epochs=20)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/20
# 1000/1000 [==============================] - 0s 93us/step - loss: 0.6910 - accuracy: 0.5800
# Epoch 2/20
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.6483 - accuracy: 0.6940
# Epoch 3/20
# 1000/1000 [==============================] - 0s 22us/step - loss: 0.5620 - accuracy: 0.8180
# Epoch 4/20
# 1000/1000 [==============================] - 0s 21us/step - loss: 0.4623 - accuracy: 0.8480
# Epoch 5/20
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.3678 - accuracy: 0.8800
# Epoch 6/20
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.2769 - accuracy: 0.9430
# Epoch 7/20
# 1000/1000 [==============================] - 0s 24us/step - loss: 0.1933 - accuracy: 0.9960
# Epoch 8/20
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.1413 - accuracy: 0.9980
# Epoch 9/20
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.1088 - accuracy: 0.9990
# Epoch 10/20
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0883 - accuracy: 1.0000
# Epoch 11/20
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.0743 - accuracy: 1.0000
# Epoch 12/20
# 1000/1000 [==============================] - 0s 31us/step - loss: 0.0640 - accuracy: 1.0000
# Epoch 13/20
# 1000/1000 [==============================] - 0s 32us/step - loss: 0.0564 - accuracy: 1.0000
# Epoch 14/20
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.0502 - accuracy: 1.0000
# Epoch 15/20
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 16/20
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0416 - accuracy: 1.0000
# Epoch 17/20
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 18/20
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 19/20
# 1000/1000 [==============================] - 0s 33us/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 20/20
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.0309 - accuracy: 1.0000

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5,1,'Blue circles and Red crosses')
